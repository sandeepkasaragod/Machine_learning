# %%
# This section is a begining of dealing the intermediate data for the prediction. 
# Here we are dealing with a mixed type of data i.e text and floating values
# The data can be downloaded from https://www.kaggle.com/datasets/ahmad10raza/breast-cancer-data/code

# Aim of this task is to predict the patient status (dead/alive) by using the various parameters/features 
# described in the data

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np
import pandas as pd

# %%
# load the dat using pandas
df = pd.read_csv("breast_cancer_data.csv", sep=",")

# %%
# print the header
df
# Out:
#      Unnamed: 0    Patient_ID   Age  Gender  Protein1  Protein2  Protein3  \
# 0             0  TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715
# 1             1  TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447
# 2             2  TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747
# 3             3  TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304
# 4             4  TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045
# ..          ...           ...   ...     ...       ...       ...       ...
# 336         336           NaN   NaN     NaN       NaN       NaN       NaN
# 337         337           NaN   NaN     NaN       NaN       NaN       NaN
# 338         338           NaN   NaN     NaN       NaN       NaN       NaN
# 339         339           NaN   NaN     NaN       NaN       NaN       NaN
# 340         340           NaN   NaN     NaN       NaN       NaN       NaN
#
#      Protein4 Tumour_Stage                      Histology ER status PR status  \
# 0    0.273680          III  Infiltrating Ductal Carcinoma  Positive  Positive
# 1   -0.031505           II             Mucinous Carcinoma  Positive  Positive
# 2   -0.234260          III  Infiltrating Ductal Carcinoma  Positive  Positive
# 3    0.124270           II  Infiltrating Ductal Carcinoma  Positive  Positive
# 4   -0.311990           II  Infiltrating Ductal Carcinoma  Positive  Positive
# ..        ...          ...                            ...       ...       ...
# 336       NaN          NaN                            NaN       NaN       NaN
# 337       NaN          NaN                            NaN       NaN       NaN
# 338       NaN          NaN                            NaN       NaN       NaN
# 339       NaN          NaN                            NaN       NaN       NaN
# 340       NaN          NaN                            NaN       NaN       NaN
#
#     HER2 status                 Surgery_type Date_of_Surgery  \
# 0      Negative  Modified Radical Mastectomy       15-Jan-17
# 1      Negative                   Lumpectomy       26-Apr-17
# 2      Negative                        Other       08-Sep-17
# 3      Negative  Modified Radical Mastectomy       25-Jan-17
# 4      Negative                        Other       06-May-17
# ..          ...                          ...             ...
# 336         NaN                          NaN             NaN
# 337         NaN                          NaN             NaN
# 338         NaN                          NaN             NaN
# 339         NaN                          NaN             NaN
# 340         NaN                          NaN             NaN
#
#     Date_of_Last_Visit Patient_Status
# 0            19-Jun-17          Alive
# 1            09-Nov-18           Dead
# 2            09-Jun-18          Alive
# 3            12-Jul-17          Alive
# 4            27-Jun-19           Dead
# ..                 ...            ...
# 336                NaN            NaN
# 337                NaN            NaN
# 338                NaN            NaN
# 339                NaN            NaN
# 340                NaN            NaN
#
# [341 rows x 17 columns]

# %%
# you could see different types of columns including floating points (protein1, protein2...age) 
# and categorical values (tumor stage, ER status ..... ) 
# as well as NaN at the end of the file

# Well the categorical values needs to be converted to integers to build the model
# Also the NaN needs to be removed as well.

# Lets begin the work

# %%
#droping the NaN
df = df.dropna()

# %%
# for now we are not dealing with dates therefor we can remove 
# "Date_of_Surgery" and "Date_of_Last_Visit" and Patient_ID columns
df = df.drop(["Patient_ID", "Date_of_Last_Visit", "Date_of_Surgery"], axis=1)

# %%
#droping the first column
df = df.drop(df.columns[0], axis=1)

# %%
df
# Out:
#       Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0    36.0  FEMALE  0.080353   0.42638   0.54715  0.273680          III
# 1    43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505           II
# 2    69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260          III
# 3    56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270           II
# 4    56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990           II
# ..    ...     ...       ...       ...       ...       ...          ...
# 329  36.0  FEMALE  0.231800   0.61804  -0.55779 -0.517350          III
# 330  44.0    MALE  0.732720   1.11170  -0.26952 -0.354920           II
# 331  61.0  FEMALE -0.719470   2.54850  -0.15024  0.339680           II
# 332  79.0  FEMALE  0.479400   2.05590  -0.53136 -0.188480            I
# 333  76.0  FEMALE -0.244270   0.92556  -0.41823 -0.067848            I
#
#                           Histology ER status PR status HER2 status  \
# 0     Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 1                Mucinous Carcinoma  Positive  Positive    Negative
# 2     Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 3     Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 4     Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# ..                              ...       ...       ...         ...
# 329   Infiltrating Ductal Carcinoma  Positive  Positive    Positive
# 330  Infiltrating Lobular Carcinoma  Positive  Positive    Negative
# 331   Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 332   Infiltrating Ductal Carcinoma  Positive  Positive    Positive
# 333   Infiltrating Ductal Carcinoma  Positive  Positive    Negative
#
#                     Surgery_type Patient_Status
# 0    Modified Radical Mastectomy          Alive
# 1                     Lumpectomy           Dead
# 2                          Other          Alive
# 3    Modified Radical Mastectomy          Alive
# 4                          Other           Dead
# ..                           ...            ...
# 329            Simple Mastectomy           Dead
# 330                        Other           Dead
# 331                   Lumpectomy           Dead
# 332                   Lumpectomy           Dead
# 333                   Lumpectomy           Dead
#
# [317 rows x 13 columns]

# %%
# getting the distinct values from the categorical columns 
print ("Gender", df['Gender'].unique())
print ("Tumour_Stage", df['Tumour_Stage'].unique())
print ("Histology", df['Histology'].unique())
print ("ER status", df['ER status'].unique())
print ("PR status", df['PR status'].unique())
print ("HER2 status", df['HER2 status'].unique())
print ("Surgery_type", df['Surgery_type'].unique())
print ("Patient_Status", df['Patient_Status'].unique())
# Out:
# Gender ['FEMALE' 'MALE']
# Tumour_Stage ['III' 'II' 'I']
# Histology ['Infiltrating Ductal Carcinoma' 'Mucinous Carcinoma'
#  'Infiltrating Lobular Carcinoma']
# ER status ['Positive']
# PR status ['Positive']
# HER2 status ['Negative' 'Positive']
# Surgery_type ['Modified Radical Mastectomy' 'Lumpectomy' 'Other' 'Simple Mastectomy']
# Patient_Status ['Alive' 'Dead']

# %%
# converting the above categorical columns to integers
df['Gender'] = df['Gender'].map({'FEMALE':1, 'MALE':0})

df['Histology'] = df['Histology'].map({'Infiltrating Ductal Carcinoma':1, 'Mucinous Carcinoma':2, 
                                             'Infiltrating Lobular Carcinoma': 3})

df['Tumour_Stage'] = df['Tumour_Stage'].map({'III':3, 'II':2, 'I':1})

df['ER status'] = df['ER status'].map({'Positive':1})

df['PR status'] = df['PR status'].map({'Positive':1})

df['HER2 status'] = df['HER2 status'].map({'Negative':0, 'Positive':1})

df['Surgery_type'] = df['Surgery_type'].map({'Modified Radical Mastectomy':1, 'Lumpectomy':2, 'Other':3, 
                                             'Simple Mastectomy':4})

df['Patient_Status'] = df['Patient_Status'].map({'Alive':1, 'Dead':0})

# %%
# write the processed data to a file, can be used for my next examples
df.to_csv("preprocessed.csv", sep=",", index=False, header=True)

# %%
# load the preprocessed data
df = pd.read_csv("preprocessed.csv", sep=",")

# %%
df
# Out:
#       Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0    36.0       1  0.080353   0.42638   0.54715  0.273680             3
# 1    43.0       1 -0.420320   0.57807   0.61447 -0.031505             2
# 2    69.0       1  0.213980   1.31140  -0.32747 -0.234260             3
# 3    56.0       1  0.345090  -0.21147  -0.19304  0.124270             2
# 4    56.0       1  0.221550   1.90680   0.52045 -0.311990             2
# ..    ...     ...       ...       ...       ...       ...           ...
# 312  36.0       1  0.231800   0.61804  -0.55779 -0.517350             3
# 313  44.0       0  0.732720   1.11170  -0.26952 -0.354920             2
# 314  61.0       1 -0.719470   2.54850  -0.15024  0.339680             2
# 315  79.0       1  0.479400   2.05590  -0.53136 -0.188480             1
# 316  76.0       1 -0.244270   0.92556  -0.41823 -0.067848             1
#
#      Histology  ER status  PR status  HER2 status  Surgery_type  \
# 0            1          1          1            0             1
# 1            2          1          1            0             2
# 2            1          1          1            0             3
# 3            1          1          1            0             1
# 4            1          1          1            0             3
# ..         ...        ...        ...          ...           ...
# 312          1          1          1            1             4
# 313          3          1          1            0             3
# 314          1          1          1            0             2
# 315          1          1          1            1             2
# 316          1          1          1            0             2
#
#      Patient_Status
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 0
# ..              ...
# 312               0
# 313               0
# 314               0
# 315               0
# 316               0
#
# [317 rows x 13 columns]

# %%
# lets model it
# list the number of columns, i.e. header
header_names = df.columns.to_list()

# %%
X = df[['Age',
 'Gender',
 'Protein1',
 'Protein2',
 'Protein3',
 'Protein4',
 'Tumour_Stage',
 'Histology',
 'ER status',
 'PR status',
 'HER2 status',
 '13']].values

y = df[['Patient_Status']].values

# %%
#set up the layer
model = Sequential()
model.add(Dense(13, input_dim=12, activation='relu'))
model.add(Dense(13, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
X.shape
# Out:
# (317, 12)

# %%
model.fit(X, y, epochs=100, batch_size=16)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 3ms/step - loss: 0.8865 - accuracy: 0.8044
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5197 - accuracy: 0.7886
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5162 - accuracy: 0.8044
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5140 - accuracy: 0.8044
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5152 - accuracy: 0.8044
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.8044
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.8044
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5000 - accuracy: 0.8044
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5010 - accuracy: 0.8044
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5011 - accuracy: 0.8044
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4979 - accuracy: 0.8044
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5010 - accuracy: 0.8044
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4988 - accuracy: 0.8044
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5010 - accuracy: 0.8044
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5020 - accuracy: 0.8044
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5058 - accuracy: 0.8044
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5023 - accuracy: 0.8044
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4986 - accuracy: 0.8044
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4959 - accuracy: 0.8044
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.8044
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4949 - accuracy: 0.8044
# Epoch 22/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4948 - accuracy: 0.8044
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4938 - accuracy: 0.8044
# Epoch 24/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4957 - accuracy: 0.8044
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4962 - accuracy: 0.8044
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4978 - accuracy: 0.8044
# Epoch 27/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.8044
# Epoch 28/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4994 - accuracy: 0.8044
# Epoch 29/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5001 - accuracy: 0.8044
# Epoch 30/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4957 - accuracy: 0.8044
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.8044
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4911 - accuracy: 0.8044
# Epoch 33/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4933 - accuracy: 0.8044
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4921 - accuracy: 0.8044
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5003 - accuracy: 0.8044
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.8044
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4928 - accuracy: 0.8044
# Epoch 38/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4909 - accuracy: 0.8044
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4937 - accuracy: 0.8044
# Epoch 40/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4937 - accuracy: 0.8044
# Epoch 41/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4932 - accuracy: 0.8044
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4927 - accuracy: 0.8044
# Epoch 43/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4904 - accuracy: 0.8044
# Epoch 44/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4886 - accuracy: 0.8044
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4882 - accuracy: 0.8044
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4921 - accuracy: 0.8044
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4982 - accuracy: 0.8044
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4879 - accuracy: 0.8044
# Epoch 49/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4891 - accuracy: 0.8044
# Epoch 50/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4881 - accuracy: 0.8044
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4900 - accuracy: 0.8044
# Epoch 52/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4886 - accuracy: 0.8044
# Epoch 53/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4875 - accuracy: 0.8044
# Epoch 54/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4889 - accuracy: 0.8044
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.8044
# Epoch 56/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4862 - accuracy: 0.8044
# Epoch 57/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4856 - accuracy: 0.8044
# Epoch 58/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4886 - accuracy: 0.8044
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4852 - accuracy: 0.8044
# Epoch 60/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4848 - accuracy: 0.8044
# Epoch 61/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4869 - accuracy: 0.8044
# Epoch 62/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4873 - accuracy: 0.8044
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4859 - accuracy: 0.8044
# Epoch 64/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4848 - accuracy: 0.8044
# Epoch 65/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4870 - accuracy: 0.8044
# Epoch 66/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4857 - accuracy: 0.8044
# Epoch 67/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4931 - accuracy: 0.8044
# Epoch 68/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4869 - accuracy: 0.8044
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4848 - accuracy: 0.8044
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4864 - accuracy: 0.8044
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4831 - accuracy: 0.8044
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4830 - accuracy: 0.8044
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4800 - accuracy: 0.8044
# Epoch 74/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4838 - accuracy: 0.8044
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4820 - accuracy: 0.8044
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4823 - accuracy: 0.8044
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4827 - accuracy: 0.8044
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4823 - accuracy: 0.8044
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4877 - accuracy: 0.8044
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4841 - accuracy: 0.8044
# Epoch 81/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4914 - accuracy: 0.8044
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4919 - accuracy: 0.8044
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4921 - accuracy: 0.8044
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4817 - accuracy: 0.8044
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4799 - accuracy: 0.8044
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4814 - accuracy: 0.8044
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4786 - accuracy: 0.8044
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4824 - accuracy: 0.8044
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4800 - accuracy: 0.8044
# Epoch 90/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4810 - accuracy: 0.8044
# Epoch 91/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4856 - accuracy: 0.8044
# Epoch 92/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4830 - accuracy: 0.8013
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4838 - accuracy: 0.8044
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4800 - accuracy: 0.8044
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.8044
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4795 - accuracy: 0.8044
# Epoch 97/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4853 - accuracy: 0.8044
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4823 - accuracy: 0.8044
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4772 - accuracy: 0.8044
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.8044

# %%
accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy[1]*100))
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4743 - accuracy: 0.8044
# Accuracy: 80.44

# %%
# Great, we managed to get 80% accuracy which is not bad on small datasets like the one implemented
